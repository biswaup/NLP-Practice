# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# You will need to change the following directory path according to your own path
#cd drive/My Drive/Recsys-2019/sequence_classifier
# Out:
# /content/drive/My Drive/Recsys-2019/sequence_classifier

# %%
# Absolute path
#os.listdir('/content/drive/My Drive/TUE -EIT (me)/Recommender Systems/Assignment 3 - Sequential networks/Aspect Level/')
absolute_path = '/content/drive/My Drive/TUE -EIT (me)/Recommender Systems/Assignment 3 - Sequential networks/Aspect Level/'

# %%
import os
import sys
import codecs
import operator
import numpy as np
import re
from time import time

# %%
import _pickle as cPickle

# %%
aspect_path = absolute_path + 'data/aspect_level-sentiment/aspect_level'

# %%
doc_path = absolute_path + 'data/doc_level-sentiment/doc_level'

# %%
### Reading preprocess data

# %%
def read_pickle(data_path, file_name):

    f = open(os.path.join(data_path, file_name), 'rb')
    read_file = cPickle.load(f)
    f.close()

    return read_file

def save_pickle(data_path, file_name, data):

    f = open(os.path.join(data_path, file_name), 'wb')
    cPickle.dump(data, f)
    print(" file saved to: %s"%(os.path.join(data_path, file_name)))
    f.close()

# %%
vocab = read_pickle(aspect_path, 'all_vocab.pkl')

train_x = read_pickle(aspect_path, 'train_x.pkl')
train_y = read_pickle(aspect_path, 'train_y.pkl')
dev_x = read_pickle(aspect_path, 'dev_x.pkl')
dev_y = read_pickle(aspect_path, 'dev_y.pkl')
test_x = read_pickle(aspect_path, 'test_x.pkl')
test_y = read_pickle(aspect_path, 'test_y.pkl')

train_aspect = read_pickle(aspect_path, 'train_aspect.pkl')
dev_aspect = read_pickle(aspect_path, 'dev_aspect.pkl')
test_aspect = read_pickle(aspect_path, 'test_aspect.pkl')


pretrain_data = read_pickle(aspect_path, 'pretrain_data.pkl')
pretrain_label = read_pickle(aspect_path, 'pretrain_label.pkl')

# %% [markdown]
# ### Batch generator and data iterator

# %%
class Dataiterator():
    '''
      1) Iteration over minibatches using next(); call reset() between epochs to randomly shuffle the data
      2) Access to the entire dataset using all()
    '''
    
    def __init__(self, aspect_data, doc_data, seq_length=32, decoder_dim=300, batch_size=32):
        
        len_aspect_data = len(aspect_data[0])
        len_doc_data = len(doc_data[0])
        
        self.X_aspect = aspect_data[0] 
        self.y_aspect = aspect_data[1]
        self.aspect_terms = aspect_data[2]
        
        self.X_doc = doc_data[0]
        self.y_doc = doc_data[1]
        
        self.num_data = len_aspect_data
        self.batch_size = batch_size # batch size
        self.reset() # initial: shuffling examples and set index to 0
    
    def __iter__(self): # iterates data
        return self


    def reset(self): # initials
        self.idx = 0
        self.order = np.random.permutation(self.num_data) # shuffling examples by providing randomized ids 
        
    def __next__(self): # return model inputs - outputs per batch
        
        X_ids = [] # hold ids per batch 
        while len(X_ids) < self.batch_size:
            X_id = self.order[self.idx] # copy random id from initial shuffling
            X_ids.append(X_id)
            self.idx += 1 # 
            if self.idx >= self.num_data: # exception if all examples of data have been seen (iterated)
                self.reset()
                raise StopIteration()
                
        batch_X_aspect = self.X_aspect[np.array(X_ids)] # X values (encoder input) per batch
        batch_y_aspect = self.y_aspect[np.array(X_ids)] # y_in values (decoder input) per batch
        batch_aspect_terms = self.aspect_terms[np.array(X_ids)]
        batch_X_doc = self.X_doc[np.array(X_ids)]
        batch_y_doc = self.y_doc[np.array(X_ids)]
        
        
        return batch_X_aspect, batch_y_aspect, batch_aspect_terms, batch_X_doc, batch_y_doc

          
    def all(self): # return all data examples
        return self.X_aspect, self.y_aspect, self.aspect_terms, self.X_doc, self.y_doc

# %% [markdown]
# ### Model

# %%
from keras.models import Model
from keras.layers import Input, Embedding, Dense, Lambda, Dropout, LSTM
from keras.layers import Reshape, Activation, RepeatVector, concatenate, Concatenate, Dot, Multiply
# Out:
# Using TensorFlow backend.

# %%
import keras.backend as K
from keras.engine.topology import Layer
from keras import initializers
from keras import regularizers
from keras import constraints

# %% [markdown]
# ### Attention Network

# %%
# overal_maxlen = 82
# overal_maxlen_aspect = 7
overal_maxlen = 74
overal_maxlen_aspect = 18

# %%
def custom_softmax(x, axis=1):
            """Softmax activation function.
            # Arguments
                x : Tensor.
                axis: Integer, axis along which the softmax normalization is applied.
            # Returns
                Tensor, output of softmax transformation.
            # Raises
                ValueError: In case `dim(x) == 1`.
            """
            ndim = K.ndim(x)
            if ndim == 2:
                return K.softmax(x)
            elif ndim > 2:
                e = K.exp(x - K.max(x, axis=axis, keepdims=True))
                s = K.sum(e, axis=axis, keepdims=True)
                return e / s
            else:
                raise ValueError('Cannot apply softmax to a tensor that is 1D')

# %%
repeator = RepeatVector(overal_maxlen, name='repeator_att')
concatenator = Concatenate(axis=-1, name='concator_att')
densor1 = Dense(300, activation = "tanh", name='densor1_att')
densor2 = Dense(1, activation = "relu", name='densor2_att')
activator = Activation(custom_softmax, name='attention_weights')
dotor = Dot(axes = 1, name='dotor_att')

# %%
def attention(keys, query):
    
    query = repeator(query)
    print("query shape: %s" %str(query._keras_shape))
    concat = concatenator([keys, query])
    print("concat shape: %s" %str(concat._keras_shape))
    e1 = densor1(concat)
    print("e1 shape: %s" %str(e1._keras_shape))
    e2 = densor2(e1)
    print("e2 shape: %s" %str(e2._keras_shape))
    alphas = activator(e2)
    print("alphas shape: %s" %str(alphas._keras_shape))
    context = dotor([alphas, keys])
    print("context shape: %s" %str(context._keras_shape))
    
    return context, alphas

# %%
class Average(Layer):
  
    def __init__(self, mask_zero=True, **kwargs):
        self.mask_zero = mask_zero
        self.supports_masking = True
        super(Average, self).__init__(**kwargs)

    def call(self, x, mask=None):
        if self.mask_zero:
            mask = K.cast(mask, K.floatx())
            mask = K.expand_dims(mask)
            x = x * mask
            return K.sum(x, axis=1) / (K.sum(mask, axis=1) + K.epsilon())
        else:
            return K.mean(x, axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[-1])
    
    def compute_mask(self, x, mask):
        return None

# %% [markdown]
# ### Main model

# %%
dropout = 0.5     
recurrent_dropout = 0.1
vocab_size = len(vocab)
num_outputs = 3 # labels

# %% [markdown]
# ### Inputs: How many inputs do you need for the current task?

# %%
##### Inputs #####
sentence_input = Input(shape=(overal_maxlen,), dtype='int32', name='sentence_input')
aspect_input = Input(shape=(overal_maxlen_aspect,), dtype='int32', name='aspect_input')
pretrain_input = Input(shape=(None,), dtype='int32', name='pretrain_input')

# %% [markdown]
# ### Word-level embedding (shareable between all model inputs)

# %%
##### construct word embedding layer #####
word_emb = Embedding(vocab_size, 300, mask_zero=True, name='word_emb')

# %% [markdown]
# ### Aspect-level representation (averaged)

# %%
### represent aspect as averaged word embedding ###
print ('use average term embs as aspect embedding')
aspect_term_embs = word_emb(aspect_input)
aspect_embs = Average(mask_zero=True, name='aspect_emb')(aspect_term_embs)
# Out:
# use average term embs as aspect embedding

# %%
aspect_embs.shape
# Out:
# TensorShape([Dimension(None), Dimension(300)])

# %% [markdown]
# ### Sentence-level representation from two domains

# %%
### sentence representation ###
sentence_embs = word_emb(sentence_input) # from aspect-level domain
pretrain_embs = word_emb(pretrain_input) # from document-level domain

# %% [markdown]
# ### LSTM layer (shared between three representations)

# %%
rnn = LSTM(300, return_sequences=True, dropout=dropout, recurrent_dropout=recurrent_dropout, name='lstm')

# %%
sentence_lstm = rnn(sentence_embs)
pretrain_lstm = rnn(pretrain_embs)

# %%
# UNCOMMENT REPLACE KEYS?, QUERY? WITH THE CORRESPONDING TENSORS AS ATTENTION KEYS AND QUERY

#att_context, att_weights = attention(KEYS?, QUERY?)

# %%
att_context, att_weights = attention(sentence_lstm, aspect_embs)
# Out:
# query shape: (None, 74, 300)
# concat shape: (None, 74, 600)
# e1 shape: (None, 74, 300)
# e2 shape: (None, 74, 1)
# alphas shape: (None, 74, 1)
# context shape: (None, 1, 300)

# %%
pretrain_avg = Average(mask_zero=True)(pretrain_lstm)

sentence_output = Dense(num_outputs, name='dense_1')(att_context)
pretrain_output = Dense(num_outputs, name='dense_2')(pretrain_avg)

# %%
print("sentence_output shape: %s" % str(sentence_output._keras_shape))
# Out:
# sentence_output shape: (None, 1, 3)

# %%
sentence_output = Reshape((num_outputs,))(sentence_output)

# %%
print("sentence_output shape: %s" % str(sentence_output._keras_shape))
# Out:
# sentence_output shape: (None, 3)

# %%
aspect_probs = Activation('softmax', name='aspect_model')(sentence_output)
doc_probs = Activation('softmax', name='pretrain_model')(pretrain_output)

# %%
model = Model(inputs=[sentence_input, aspect_input, pretrain_input], outputs=[aspect_probs, doc_probs])

# %%
import keras.optimizers as opt

optimizer = opt.RMSprop(lr=0.001, rho=0.9, epsilon=1e-06, clipnorm=10, clipvalue=0)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sentence_input (InputLayer)     (None, 74)           0
# __________________________________________________________________________________________________
# aspect_input (InputLayer)       (None, 18)           0
# __________________________________________________________________________________________________
# word_emb (Embedding)            multiple             3000900     aspect_input[0][0]
#                                                                  sentence_input[0][0]
#                                                                  pretrain_input[0][0]
# __________________________________________________________________________________________________
# aspect_emb (Average)            (None, 300)          0           word_emb[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     multiple             721200      word_emb[1][0]
#                                                                  word_emb[2][0]
# __________________________________________________________________________________________________
# repeator_att (RepeatVector)     (None, 74, 300)      0           aspect_emb[0][0]
# __________________________________________________________________________________________________
# concator_att (Concatenate)      (None, 74, 600)      0           lstm[0][0]
#                                                                  repeator_att[0][0]
# __________________________________________________________________________________________________
# densor1_att (Dense)             (None, 74, 300)      180300      concator_att[0][0]
# __________________________________________________________________________________________________
# densor2_att (Dense)             (None, 74, 1)        301         densor1_att[0][0]
# __________________________________________________________________________________________________
# pretrain_input (InputLayer)     (None, None)         0
# __________________________________________________________________________________________________
# attention_weights (Activation)  (None, 74, 1)        0           densor2_att[0][0]
# __________________________________________________________________________________________________
# dotor_att (Dot)                 (None, 1, 300)       0           attention_weights[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 3)         903         dotor_att[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 300)          0           lstm[1][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 3)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            903         average_2[0][0]
# __________________________________________________________________________________________________
# aspect_model (Activation)       (None, 3)            0           reshape_2[0][0]
# __________________________________________________________________________________________________
# pretrain_model (Activation)     (None, 3)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 3,904,507
# Trainable params: 3,904,507
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=optimizer,
              loss={'aspect_model': 'categorical_crossentropy', 'pretrain_model': 'categorical_crossentropy'},
              loss_weights = {'aspect_model': 1, 'pretrain_model': 0.1},
              metrics = {'aspect_model': 'categorical_accuracy', 'pretrain_model': 'categorical_accuracy'})

# %% [markdown]
# ### Training

# %%
batch_size = 32

# %%
pretrain_data.shape
# Out:
# (30000, 300)

# %%
pretrain_data= np.array(pretrain_data)

# %%
train_steps_epoch = len(train_x)/batch_size
batch_train_iter = Dataiterator([train_x, train_y, train_aspect], \
                                [pretrain_data, pretrain_label], batch_size)

# %%
val_steps_epoch = len(dev_x)/batch_size
batch_val_iter = Dataiterator([dev_x, dev_y, dev_aspect], \
                              [pretrain_data, pretrain_label], batch_size)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

def train_generator(model, batch_train_iter, batch_val_iter):
    
    earlystop_callbacks = [EarlyStopping(monitor='val_loss', patience=10),
                     ModelCheckpoint(filepath=os.path.join('./','{epoch:02d}-{loss:.2f}.check'), \
                                     monitor='val_loss', save_best_only=False, \
                                     save_weights_only=True)
                     ]
    
    def train_gen():
        while True:
            train_batches = [[[X, aspect, pretrain_X], [y, pretrain_y]] for X, y, \
                             aspect, pretrain_X, pretrain_y in batch_train_iter]
            for train_batch in train_batches:
                yield train_batch
                
    def val_gen():
        while True:
            val_batches = [[[X, aspect, pretrain_X], [y, pretrain_y]] for X, y, \
                           aspect, pretrain_X, pretrain_y in batch_val_iter]
            for val_batch in val_batches:
                yield val_batch
                
    history = model.fit_generator(train_gen(), validation_data=val_gen(), \
                                  validation_steps=val_steps_epoch, steps_per_epoch=train_steps_epoch, \
                                  epochs = 20, callbacks = earlystop_callbacks)

# %%
train_batches = [[[X, aspect, pretrain_X], [y, pretrain_y]] for X, y, \
                             aspect, pretrain_X, pretrain_y in batch_train_iter]

# %%
print(train_batches[0][0][0].shape)
print(train_batches[0][0][1].shape)
print(train_batches[0][0][2].shape)
print(train_batches[0][1][0].shape)
print(train_batches[0][1][1].shape)
print(len(train_batches[0][0]))
# Out:
# (32, 74)
# (32, 18)
# (32, 300)
# (32, 3)
# (32, 3)
# 3

# %%
train_generator(model, batch_train_iter, batch_val_iter)
# Out:
# Epoch 1/20
# 91/90 [==============================] - 85s 936ms/step - loss: 1.0514 - aspect_model_loss: 0.9587 - pretrain_model_loss: 0.9261 - aspect_model_categorical_accuracy: 0.6003 - pretrain_model_categorical_accuracy: 0.5793 - val_loss: 0.8704 - val_aspect_model_loss: 0.8047 - val_pretrain_model_loss: 0.6569 - val_aspect_model_categorical_accuracy: 0.6685 - val_pretrain_model_categorical_accuracy: 0.7690
# Epoch 2/20
# 91/90 [==============================] - 80s 880ms/step - loss: 0.8079 - aspect_model_loss: 0.7311 - pretrain_model_loss: 0.7677 - aspect_model_categorical_accuracy: 0.6758 - pretrain_model_categorical_accuracy: 0.6755 - val_loss: 0.8278 - val_aspect_model_loss: 0.7755 - val_pretrain_model_loss: 0.5230 - val_aspect_model_categorical_accuracy: 0.6848 - val_pretrain_model_categorical_accuracy: 0.7880
# Epoch 3/20
# 91/90 [==============================] - 80s 881ms/step - loss: 0.7308 - aspect_model_loss: 0.6626 - pretrain_model_loss: 0.6821 - aspect_model_categorical_accuracy: 0.7208 - pretrain_model_categorical_accuracy: 0.7188 - val_loss: 0.7385 - val_aspect_model_loss: 0.6893 - val_pretrain_model_loss: 0.4921 - val_aspect_model_categorical_accuracy: 0.6997 - val_pretrain_model_categorical_accuracy: 0.7976
# Epoch 4/20
# 91/90 [==============================] - 81s 889ms/step - loss: 0.6652 - aspect_model_loss: 0.6023 - pretrain_model_loss: 0.6291 - aspect_model_categorical_accuracy: 0.7541 - pretrain_model_categorical_accuracy: 0.7411 - val_loss: 0.8494 - val_aspect_model_loss: 0.7952 - val_pretrain_model_loss: 0.5414 - val_aspect_model_categorical_accuracy: 0.6889 - val_pretrain_model_categorical_accuracy: 0.7948
# Epoch 5/20
# 91/90 [==============================] - 79s 868ms/step - loss: 0.5975 - aspect_model_loss: 0.5368 - pretrain_model_loss: 0.6065 - aspect_model_categorical_accuracy: 0.7916 - pretrain_model_categorical_accuracy: 0.7424 - val_loss: 0.7471 - val_aspect_model_loss: 0.7034 - val_pretrain_model_loss: 0.4371 - val_aspect_model_categorical_accuracy: 0.7052 - val_pretrain_model_categorical_accuracy: 0.8261
# Epoch 6/20
# 91/90 [==============================] - 79s 868ms/step - loss: 0.5519 - aspect_model_loss: 0.4969 - pretrain_model_loss: 0.5500 - aspect_model_categorical_accuracy: 0.8063 - pretrain_model_categorical_accuracy: 0.7658 - val_loss: 0.7262 - val_aspect_model_loss: 0.6887 - val_pretrain_model_loss: 0.3757 - val_aspect_model_categorical_accuracy: 0.7147 - val_pretrain_model_categorical_accuracy: 0.8777
# Epoch 7/20
# 91/90 [==============================] - 80s 876ms/step - loss: 0.5031 - aspect_model_loss: 0.4518 - pretrain_model_loss: 0.5136 - aspect_model_categorical_accuracy: 0.8245 - pretrain_model_categorical_accuracy: 0.7837 - val_loss: 0.7616 - val_aspect_model_loss: 0.7200 - val_pretrain_model_loss: 0.4152 - val_aspect_model_categorical_accuracy: 0.7120 - val_pretrain_model_categorical_accuracy: 0.8207
# Epoch 8/20
# 91/90 [==============================] - 81s 889ms/step - loss: 0.4800 - aspect_model_loss: 0.4292 - pretrain_model_loss: 0.5081 - aspect_model_categorical_accuracy: 0.8300 - pretrain_model_categorical_accuracy: 0.7926 - val_loss: 0.7813 - val_aspect_model_loss: 0.7430 - val_pretrain_model_loss: 0.3833 - val_aspect_model_categorical_accuracy: 0.6807 - val_pretrain_model_categorical_accuracy: 0.8804
# Epoch 9/20
# 91/90 [==============================] - 79s 868ms/step - loss: 0.4425 - aspect_model_loss: 0.3960 - pretrain_model_loss: 0.4647 - aspect_model_categorical_accuracy: 0.8427 - pretrain_model_categorical_accuracy: 0.8128 - val_loss: 0.7604 - val_aspect_model_loss: 0.7262 - val_pretrain_model_loss: 0.3421 - val_aspect_model_categorical_accuracy: 0.6875 - val_pretrain_model_categorical_accuracy: 0.8818
# Epoch 10/20
# 91/90 [==============================] - 79s 865ms/step - loss: 0.4229 - aspect_model_loss: 0.3804 - pretrain_model_loss: 0.4249 - aspect_model_categorical_accuracy: 0.8489 - pretrain_model_categorical_accuracy: 0.8266 - val_loss: 0.7924 - val_aspect_model_loss: 0.7590 - val_pretrain_model_loss: 0.3339 - val_aspect_model_categorical_accuracy: 0.7092 - val_pretrain_model_categorical_accuracy: 0.8668
# Epoch 11/20
# 91/90 [==============================] - 79s 873ms/step - loss: 0.4028 - aspect_model_loss: 0.3625 - pretrain_model_loss: 0.4035 - aspect_model_categorical_accuracy: 0.8537 - pretrain_model_categorical_accuracy: 0.8455 - val_loss: 0.8187 - val_aspect_model_loss: 0.7901 - val_pretrain_model_loss: 0.2862 - val_aspect_model_categorical_accuracy: 0.7011 - val_pretrain_model_categorical_accuracy: 0.8940
# Epoch 12/20
# 91/90 [==============================] - 80s 881ms/step - loss: 0.3721 - aspect_model_loss: 0.3346 - pretrain_model_loss: 0.3750 - aspect_model_categorical_accuracy: 0.8630 - pretrain_model_categorical_accuracy: 0.8565 - val_loss: 0.8517 - val_aspect_model_loss: 0.8252 - val_pretrain_model_loss: 0.2654 - val_aspect_model_categorical_accuracy: 0.7215 - val_pretrain_model_categorical_accuracy: 0.9103
# Epoch 13/20
# 91/90 [==============================] - 79s 865ms/step - loss: 0.3648 - aspect_model_loss: 0.3288 - pretrain_model_loss: 0.3599 - aspect_model_categorical_accuracy: 0.8606 - pretrain_model_categorical_accuracy: 0.8602 - val_loss: 0.8845 - val_aspect_model_loss: 0.8595 - val_pretrain_model_loss: 0.2499 - val_aspect_model_categorical_accuracy: 0.6875 - val_pretrain_model_categorical_accuracy: 0.9035
# Epoch 14/20
# 91/90 [==============================] - 79s 863ms/step - loss: 0.3468 - aspect_model_loss: 0.3133 - pretrain_model_loss: 0.3353 - aspect_model_categorical_accuracy: 0.8712 - pretrain_model_categorical_accuracy: 0.8753 - val_loss: 0.7887 - val_aspect_model_loss: 0.7696 - val_pretrain_model_loss: 0.1909 - val_aspect_model_categorical_accuracy: 0.7133 - val_pretrain_model_categorical_accuracy: 0.9402
# Epoch 15/20
# 91/90 [==============================] - 79s 872ms/step - loss: 0.3034 - aspect_model_loss: 0.2724 - pretrain_model_loss: 0.3103 - aspect_model_categorical_accuracy: 0.8884 - pretrain_model_categorical_accuracy: 0.8877 - val_loss: 0.9963 - val_aspect_model_loss: 0.9777 - val_pretrain_model_loss: 0.1858 - val_aspect_model_categorical_accuracy: 0.6943 - val_pretrain_model_categorical_accuracy: 0.9416
# Epoch 16/20
# 91/90 [==============================] - 80s 877ms/step - loss: 0.2979 - aspect_model_loss: 0.2694 - pretrain_model_loss: 0.2853 - aspect_model_categorical_accuracy: 0.8877 - pretrain_model_categorical_accuracy: 0.8966 - val_loss: 0.9408 - val_aspect_model_loss: 0.9233 - val_pretrain_model_loss: 0.1749 - val_aspect_model_categorical_accuracy: 0.6997 - val_pretrain_model_categorical_accuracy: 0.9361

# %%
test_steps_epoch = len(test_x)/batch_size
batch_test_iter = Dataiterator([test_x, test_y, test_aspect], \
                              [pretrain_data, pretrain_label], batch_size)

# %%
batch_test_iter.y_aspect.shape
# Out:
# (1120, 3)

# %%
batch_train_iter.y_aspect.shape
# Out:
# (2882, 3)

# %%
def test_generator(model, batch_test_iter):
    
#     earlystop_callbacks = [EarlyStopping(monitor='val_loss', patience=10),
#                      ModelCheckpoint(filepath=os.path.join('./','{epoch:02d}-{loss:.2f}.check'), \
#                                      monitor='val_loss', save_best_only=False, \
#                                      save_weights_only=True)
#                      ]
    
    def test_gen():
        while True:
            test_batches = [[[X, aspect, pretrain_X], [y, pretrain_y]] for X, y, aspect, pretrain_X, pretrain_y in batch_test_iter]
            for test_batch in test_batches:
                yield test_batch
                
                   
    history = model.predict_generator(test_gen(),  steps=train_steps_epoch)

# %%
print(len(train_batches), len(train_batches[0]), len(train_batches[0][0]), len(train_batches[0][0][0]), len(train_batches[0][0][0][0]))
print(len(test_batches), len(test_batches[0]), len(test_batches[0][0]), len(test_batches[0][0][0]), len(test_batches[0][0][0][0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-304902dfe962> in <module>()
# ----> 1 print(len(train_batches), len(train_batches[0]), len(train_batches[0][0]), len(train_batches[0][0][0]), len(train_batches[0][0][0][0]))
#       2 print(len(test_batches), len(test_batches[0]), len(test_batches[0][0]), len(test_batches[0][0][0]), len(test_batches[0][0][0][0]))
#
# NameError: name 'train_batches' is not defined

# %%
# start testing
#predictions = model.predict(test_x_, verbose = 0)
test_generator(model, batch_test_iter)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
print(test_x.shape, test_y.shape, test_aspect.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-788db6282838> in <module>()
# ----> 1 test_generator(model, batch_test_iter)
#       2 print("score: %.2f" % (score))
#       3 print("acc: %.2f" % (acc))
#       4 print(test_x.shape, test_y.shape, test_aspect.shape)
#
# <ipython-input-243-09af11d512bd> in test_generator(model, batch_test_iter)
#      14
#      15
# ---> 16     history = model.predict_generator(test_gen(),  steps=train_steps_epoch)
#      17
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1520             workers=workers,
#    1521             use_multiprocessing=use_multiprocessing,
# -> 1522             verbose=verbose)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in predict_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     451                 x = generator_output
#     452
# --> 453             outs = model.predict_on_batch(x)
#     454             outs = to_list(outs)
#     455
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_on_batch(self, x)
#    1266             Numpy array(s) of predictions.
#    1267         """
# -> 1268         x, _, _ = self._standardize_user_data(x)
#    1269         if self._uses_dynamic_learning_phase():
#    1270             ins = x + [0.]
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#      79     elif isinstance(data, list):
#      80         if isinstance(data[0], list):
# ---> 81             data = [np.asarray(d) for d in data]
#      82         elif len(names) == 1 and isinstance(data[0], (float, int)):
#      83             data = [np.asarray(data)]
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in <listcomp>(.0)
#      79     elif isinstance(data, list):
#      80         if isinstance(data[0], list):
# ---> 81             data = [np.asarray(d) for d in data]
#      82         elif len(names) == 1 and isinstance(data[0], (float, int)):
#      83             data = [np.asarray(data)]
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not broadcast input array from shape (32,74) into shape (32)

# %%
print('Training shapes: TrainX {}, TrainY {}, TrainAspect {}'.format(train_x.shape, train_y.shape, train_aspect.shape))
print('Training shapes: TestX {}, TestY {}, TestAspect {}'.format(test_x.shape, test_y.shape, test_aspect.shape))
# Out:
# Training shapes: TrainX (2882, 74), TrainY (2882, 3), TrainAspect (2882, 18)
# Training shapes: TestX (1120, 74), TestY (1120, 3), TestAspect (1120, 18)
